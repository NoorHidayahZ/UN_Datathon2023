# %%
import pandas as pd
import tabula
columns = ['state', 'river-basin', 'river', 'no-of-stations', '2019-IKA/WQI', '2019-category', '2019-class', '2020-IKA/WQI', '2020-category', '2020-class']
def extract_table(df:pd.DataFrame) -> pd.DataFrame:
    # forward fill only first column
    df.iloc[:,[0,1]] = df.iloc[:,[0,1]].ffill(axis=0)
    # replace \r with space
    df = df.replace('\r','', regex=True)
    # find the first row of first column with value 'NEGERI/STATE'
    # row = df[df.iloc[:,0] == 'NEGERI /STATE'].index[0]
    # make row 0 as header
    df.columns = columns
    # drop row 0 & 1
    # df = df.drop(df.index[range(row)])
    # reset index
    df = df.reset_index(drop=True)
    return df

# %%
pages = range(53,59) # jadual 2.2 Sederhana Tercemar
dfs = []
for page in pages:
    df = tabula.read_pdf('EQR-2020-1.pdf', pages=[page], lattice=True,stream=True, pandas_options={'header': None})[0]
    dfs.append(extract_table(df))
df = pd.concat(dfs).reset_index(drop=True)
df
# Out:
#              state                   river-basin           river  \
# 0    NEGERI /STATE  LEMBANGANSUNGAI /RIVER BASIN  SUNGAI / RIVER
# 1    NEGERI /STATE  LEMBANGANSUNGAI /RIVER BASIN             NaN
# 2           Perlis                    Sg. Perlis       Sg. Korok
# 3           Perlis                    Sg. Perlis               1
# 4            Kedah                     Sg. Kedah       Sg. Kedah
# ..             ...                           ...             ...
# 202    Sg. Sarawak                 Sg. Samarahan               2
# 203    Sg. Sarawak                 Sg. Semenggoh               1
# 204    Sg. Sarawak                    Sg. Tabuan               1
# 205    Sg. Saribas                   Sg. Saribas               1
# 206     Sg. Sibuti                   Sg. Kabuloh               2
#
#                         no-of-stations        2019-IKA/WQI 2019-category  \
# 0    BILANGANSTESEN /NUMBER OFSTATIONS                2019          2020
# 1                             IKA /WQI  KATEGORI /CATEGORY  KELAS /CLASS
# 2                                    1                  71         ST/SP
# 3                                   72               ST/SP           III
# 4                                    1                  64         ST/SP
# ..                                 ...                 ...           ...
# 202                                 70               ST/SP           III
# 203                                 77               ST/SP            II
# 204                                 73               ST/SP           III
# 205                                 80               ST/SP            II
# 206                                 68               ST/SP           III
#
#     2019-class        2020-IKA/WQI 2020-category 2020-class
# 0          NaN                 NaN           NaN        NaN
# 1     IKA /WQI  KATEGORI /CATEGORY  KELAS /CLASS        NaN
# 2          III                  75         ST/SP        III
# 3           76               ST/SP           III        NaN
# 4          III                  70         ST/SP        III
# ..         ...                 ...           ...        ...
# 202         74               ST/SP           III        NaN
# 203         71               ST/SP           III        NaN
# 204         77               ST/SP            II        NaN
# 205         74               ST/SP           III        NaN
# 206         71               ST/SP           III        NaN
#
# [207 rows x 10 columns]

# %%
# drop row 0,1, 35,36
df = df.drop(df.index[[0,1,39,40,79,80,119,120,158,159,197,198]]).reset_index(drop=True)
# # remove rows with column 1 value equal to 'LEMBANGANSUNGAVjI/RIVER BASIN' from df
# df = df[df.iloc[:,1] != 'LEMBANGANSUNGAI/RIVER BASIN'].reset_index(drop=True)
# replace with null value column 0 with value 'NEGERI/STATE'
df
# Out:
#            state    river-basin      river no-of-stations 2019-IKA/WQI  \
# 0         Perlis     Sg. Perlis  Sg. Korok              1           71
# 1         Perlis     Sg. Perlis          1             72        ST/SP
# 2          Kedah      Sg. Kedah  Sg. Kedah              1           64
# 3          Kedah     Sg. Merbok   Sg. Batu              1           66
# 4          Kedah    Sg. Bongkok          1             63        ST/SP
# ..           ...            ...        ...            ...          ...
# 190  Sg. Sarawak  Sg. Samarahan          2             70        ST/SP
# 191  Sg. Sarawak  Sg. Semenggoh          1             77        ST/SP
# 192  Sg. Sarawak     Sg. Tabuan          1             73        ST/SP
# 193  Sg. Saribas    Sg. Saribas          1             80        ST/SP
# 194   Sg. Sibuti    Sg. Kabuloh          2             68        ST/SP
#
#     2019-category 2019-class 2020-IKA/WQI 2020-category 2020-class
# 0           ST/SP        III           75         ST/SP        III
# 1             III         76        ST/SP           III        NaN
# 2           ST/SP        III           70         ST/SP        III
# 3           ST/SP        III           70         ST/SP        III
# 4             III         71        ST/SP           III        NaN
# ..            ...        ...          ...           ...        ...
# 190           III         74        ST/SP           III        NaN
# 191            II         71        ST/SP           III        NaN
# 192           III         77        ST/SP            II        NaN
# 193            II         74        ST/SP           III        NaN
# 194           III         71        ST/SP           III        NaN
#
# [195 rows x 10 columns]

# %%
mask = df.iloc[:,9].isnull()
df[mask] = df[mask].shift(axis=1)

mask = df.iloc[:,9].isnull()
df[mask] = df[mask].shift(axis=1)

# %%
df.loc[mask,'river-basin'] = None
df
# Out:
#       state  river-basin          river no-of-stations 2019-IKA/WQI  \
# 0    Perlis   Sg. Perlis      Sg. Korok              1           71
# 1      None       Perlis     Sg. Perlis              1           72
# 2     Kedah    Sg. Kedah      Sg. Kedah              1           64
# 3     Kedah   Sg. Merbok       Sg. Batu              1           66
# 4      None        Kedah    Sg. Bongkok              1           63
# ..      ...          ...            ...            ...          ...
# 190    None  Sg. Sarawak  Sg. Samarahan              2           70
# 191    None  Sg. Sarawak  Sg. Semenggoh              1           77
# 192    None  Sg. Sarawak     Sg. Tabuan              1           73
# 193    None  Sg. Saribas    Sg. Saribas              1           80
# 194    None   Sg. Sibuti    Sg. Kabuloh              2           68
#
#     2019-category 2019-class 2020-IKA/WQI 2020-category 2020-class
# 0           ST/SP        III           75         ST/SP        III
# 1           ST/SP        III           76         ST/SP        III
# 2           ST/SP        III           70         ST/SP        III
# 3           ST/SP        III           70         ST/SP        III
# 4           ST/SP        III           71         ST/SP        III
# ..            ...        ...          ...           ...        ...
# 190         ST/SP        III           74         ST/SP        III
# 191         ST/SP         II           71         ST/SP        III
# 192         ST/SP        III           77         ST/SP         II
# 193         ST/SP         II           74         ST/SP        III
# 194         ST/SP        III           71         ST/SP        III
#
# [195 rows x 10 columns]

# %%
df.iloc[:,[0,1]] = df.iloc[:,[0,1]].ffill()
df
# Out:
#        state  river-basin          river no-of-stations 2019-IKA/WQI  \
# 0     Perlis   Sg. Perlis      Sg. Korok              1           71
# 1     Perlis       Perlis     Sg. Perlis              1           72
# 2      Kedah    Sg. Kedah      Sg. Kedah              1           64
# 3      Kedah   Sg. Merbok       Sg. Batu              1           66
# 4      Kedah        Kedah    Sg. Bongkok              1           63
# ..       ...          ...            ...            ...          ...
# 190  Sarawak  Sg. Sarawak  Sg. Samarahan              2           70
# 191  Sarawak  Sg. Sarawak  Sg. Semenggoh              1           77
# 192  Sarawak  Sg. Sarawak     Sg. Tabuan              1           73
# 193  Sarawak  Sg. Saribas    Sg. Saribas              1           80
# 194  Sarawak   Sg. Sibuti    Sg. Kabuloh              2           68
#
#     2019-category 2019-class 2020-IKA/WQI 2020-category 2020-class
# 0           ST/SP        III           75         ST/SP        III
# 1           ST/SP        III           76         ST/SP        III
# 2           ST/SP        III           70         ST/SP        III
# 3           ST/SP        III           70         ST/SP        III
# 4           ST/SP        III           71         ST/SP        III
# ..            ...        ...          ...           ...        ...
# 190         ST/SP        III           74         ST/SP        III
# 191         ST/SP         II           71         ST/SP        III
# 192         ST/SP        III           77         ST/SP         II
# 193         ST/SP         II           74         ST/SP        III
# 194         ST/SP        III           71         ST/SP        III
#
# [195 rows x 10 columns]

# %%
df.describe()
# Out:
#         state river-basin      river no-of-stations 2019-IKA/WQI  \
# count     195         195        195            195          195
# unique     22          83        186             11           43
# top     Johor       Johor  Sg. Korok              1           76
# freq       38          13          2            114           14
#
#        2019-category 2019-class 2020-IKA/WQI 2020-category 2020-class
# count            195        195          195           195        195
# unique             3          3           21             1          2
# top            ST/SP        III           73         ST/SP        III
# freq             149        153           17           195        138

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state           195 non-null    object
#  1   river-basin     195 non-null    object
#  2   river           195 non-null    object
#  3   no-of-stations  195 non-null    object
#  4   2019-IKA/WQI    195 non-null    object
#  5   2019-category   195 non-null    object
#  6   2019-class      195 non-null    object
#  7   2020-IKA/WQI    195 non-null    object
#  8   2020-category   195 non-null    object
#  9   2020-class      195 non-null    object
# dtypes: object(10)
# memory usage: 15.4+ KB

# %%
df.to_excel('Jadual-2-3-sungai-sederhana-tercemar-2020.xlsx', index=False)
